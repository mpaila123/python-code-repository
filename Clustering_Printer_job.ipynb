# %%
import numpy as np
import pandas as pd
import os

# %%
# Get the current working directory
current_directory = os.getcwd()
print(f"Current working directory: {current_directory}")

# List files in the current directory
files_in_directory = os.listdir(current_directory)
print(f"Files in directory: {files_in_directory}")

# Construct the full file path
# Replace 'actual_file_name.csv' with the actual name and extension of your file
file_path = os.path.join(current_directory, 'working file_mahendra.csv')
# or provide the absolute path like: file_path = '/path/to/your/file/actual_file_name.csv'

# Read the CSV file using the file path
df_print = pd.read_csv(file_path)
# Out:
# Current working directory: /content
# Files in directory: ['.config', '.ipynb_checkpoints', 'working file_mahendra.csv', 'sample_data']
# <ipython-input-15-a82926370918>:15: DtypeWarning: Columns (0,2,3,4,5,6,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_print = pd.read_csv(file_path)

# %%
df_print.head()
# Out:
#        DeviceName  TrackingPageCount                        UserDescription  \
# 0   PHITTA-PM0031             1476.0                       Torre Annunziata
# 1   PHITTA-PM0010             1476.0                       Torre Annunziata
# 2  GXINKL-PM00006             1326.0  Kalwe (Technical Operations) (Sandoz)
# 3   PHUSMH-PM7004                1.0                               Millburn
# 4   PHUSMH-PM7004                1.0                               Millburn
#
#                                      JobName JobDateTime Serial Number  \
# 0  LIBERAZIONE-DAL-MALIGNO-Preghiere (1).pdf   27-Jan-25    CZBBS650FQ
# 1  LIBERAZIONE-DAL-MALIGNO-Preghiere (1).pdf   27-Jan-25    CZBBS5V01S
# 2                    Week_1-52_SFG_2024.xlsx    6-Feb-25    CNNKL4R5PK
# 3            Microsoft Word - SPC-WIP-121924    2-Jan-25    CN215FY0TR
# 4            Microsoft Word - SPC-WIP-121924    2-Jan-25    CN215FY0TR
#
#                   Site Site code                                        Model  \
# 0            Pharma_01      ITTA     HP Color LaserJet Managed Flow MFP E786z
# 1     Torre Annunziata      ITTA  HP Color LaserJet Enterprise Flow MFP X677z
# 2                 INKL      INKL   HP LaserJet Enterprise Managed MFP M527dnm
# 3  Millburn - NJ 07041      USMH   HP PageWide Managed Color Flow MFP E58650z
# 4  Millburn - NJ 07041      USMH   HP PageWide Managed Color Flow MFP E58650z
#
#   Country Month
# 0   Italy   Jan
# 1   Italy   Jan
# 2   India   Feb
# 3     USA   Jan
# 4     USA   Jan
