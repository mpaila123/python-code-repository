# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Data Loading**

# %%
df_printer1 = pd.read_csv("Printer job automation_csv_2nd draft.csv")

# %% [markdown]
# **Reasoning**:
# checking to confirm the data

# %%
df_printer1.head()
# Out:
#    TrackingId      SafeComName     ComputerName StartDateTime EndDateTime  \
# 0       21522  GLCHBS-SP321177  GLCHBS-SP150042       14:00.0     15:06.0
# 1       21588  GLCHBS-SP321177  GLCHBS-SP150042       25:08.0     26:15.0
# 2       21790  GLCHBS-SP321177  GLCHBS-SP150042       01:07.0     02:27.0
# 3       22020  GLCHBS-SP321177  GLCHBS-SP150042       43:19.0     45:16.0
# 4       22140  GLCHBS-SP321177  GLCHBS-SP150042       17:37.0     19:58.0
#
#    ParserPageCount  DriverPageCount  TrackingPageCount  PageCountStatus  \
# 0                5                1                  5                0
# 1                5                1                  5                0
# 2               22               22                 22                0
# 3               34               34                 34                0
# 4               45               45                 45                0
#
#    PageCountSenseCode  ...    DeviceIpAddr  \
# 0                   0  ...  86.116.111.196
# 1                   0  ...  86.116.111.196
# 2                   0  ...  86.116.111.196
# 3                   0  ...  86.116.111.196
# 4                   0  ...  86.116.111.196
#
#                                              JobName      Analysis  \
# 0  TI_LI6_SP_CasePacker_DQR_1.0_Layout_07.08.2023...  TI_LI6_SP_Ca
# 1  TI_LI6_SP_CasePacker_DQR_1.0_Layout_07.08.2023...  TI_LI6_SP_Ca
# 2                            A9ibhl16_yos226_boo.tmp  A9ibhl16_yos
# 3                          A91don03x_1ydeag9_8kw.tmp  A91don03x_1y
# 4                           A91fizdry_yos25e_boo.tmp  A91fizdry_yo
#
#   JobDateTime     JobSize                      JobDriverName  PMQueueName  \
# 0     06:50.0   7914897.0  HP Universal Printing PS (v7.0.1)  PullPrintPS
# 1     17:41.0   7914620.0  HP Universal Printing PS (v7.0.1)  PullPrintPS
# 2     59:49.0  15237480.0  HP Universal Printing PS (v7.0.1)  PullPrintPS
# 3     41:49.0  25183204.0  HP Universal Printing PS (v7.0.1)  PullPrintPS
# 4     16:53.0  40881541.0  HP Universal Printing PS (v7.0.1)  PullPrintPS
#
#    PMPortName   PMComputerName DocComputerName
# 0  Pullport13  GLCHBS-SP150048   GXSIGX-L14070
# 1  Pullport13  GLCHBS-SP150048   GXSIGX-L14070
# 2  Pullport13  GLCHBS-SP150048   GXSIGX-L14070
# 3  Pullport13  GLCHBS-SP150048   GXSIPR-L10109
# 4  Pullport13  GLCHBS-SP150048   GXSIGX-L14070
#
# [5 rows x 22 columns]

# %%
df_printer1.columns
# Out:
# Index(['TrackingId', 'SafeComName', 'ComputerName', 'StartDateTime',
#        'EndDateTime', 'ParserPageCount', 'DriverPageCount',
#        'TrackingPageCount', 'PageCountStatus', 'PageCountSenseCode',
#        'UserDescription', 'DeviceName', 'DeviceIpAddr', 'JobName', 'Analysis',
#        'JobDateTime', 'JobSize', 'JobDriverName', 'PMQueueName', 'PMPortName',
#        'PMComputerName', 'DocComputerName'],
#       dtype='object')

# %%
df_printer1.shape
# Out:
# (16016, 22)

# %% [markdown]
# Dropping Analyis tab from the dataframe

# %%
df_printer1 = df_printer1.drop("Analysis",axis=1)

# %%
df_printer1.columns
# Out:
# Index(['TrackingId', 'SafeComName', 'ComputerName', 'StartDateTime',
#        'EndDateTime', 'ParserPageCount', 'DriverPageCount',
#        'TrackingPageCount', 'PageCountStatus', 'PageCountSenseCode',
#        'UserDescription', 'DeviceName', 'DeviceIpAddr', 'JobName',
#        'JobDateTime', 'JobSize', 'JobDriverName', 'PMQueueName', 'PMPortName',
#        'PMComputerName', 'DocComputerName'],
#       dtype='object')

# %%
# creating a function to get the extension of the job name mentioned in spreadsheet

import os

def get_extension(job_name):
    job_name = str(job_name)  # Convert to string if not already
    _, ext = os.path.splitext(job_name)  # Extract extension
    return ext.lower() if ext else "no_extension"

# %%
extension_mapping = {
    ".pdf": "PDF Document",
    ".jpg": "Image File",
    ".png": "Image File",
    ".docx": "Microsoft Word Document",
    ".doc": "Microsoft Word Document",
    ".docx": "Microsoft Word Document",
    ".tmp": "Temporary System File",
    ".pptx": "Presentation Document",
    ".xls": "Excel Spreadsheet",
    ".xlsx": "Excel Spreadsheet",
    ".xlsm": "Excel Spreadsheet",
    ".xlsb": "Excel Spreadsheet",
    ".txt": "Text Document",
    ".csv": "Data File",
    ".zip": "Compressed File",
    ".log": "Log File",
    ".html": "Web Page",
    ".snagx" : "Snagit screen capture software",
    ".php": "PHP Script",
    ".oxps":"Open XML Paper Specification",
    ".asp" : "Active Server Page Extended file",
    ".ashx" : "Active Server Page Extended file",
    ".aspx" : "Active Server Page Extended file",
    }

# %%
# Classification Mapping (Example)
job_classification_dict = {
    "email job": "Email Print Job",
    "microsoft outlook - memo style": "Email Print Job",
    "qualification summary eSig Rpt": "System-Generated Report",
    "_flNUQVRFPTMwNzUwLjA0My4wNi4wMQ==": "System-Generated Report",
    "_Microsoft Word Document": "Microsoft Word Document",
    "Microsoft PowerPoint" : "Presentation Document",
    "document1.doc": "Microsoft Word Document",
    "randomfile.tmp": "Temporary System File",
    "report_final.pdf": "PDF Document",
    "meeting agenda.docx": "Microsoft Word Document",
    "scanneddocument.pdf": "Scanned PDF Document",
    "system_log_123.tmp": "Temporary System File",
    "presentation slides.pptx": "Presentation Document"
}

# %%
# Define job classification patterns (matches text anywhere in job name)
pattern_classification_dict = {
    "email job": "Email",
    "microsoft outlook": "Email Print Job",
    "Rep_Outgoing_doc" : "document",
    "Copy job" : "document",
    "qualification summary": "System-Generated Report",
    "notepad": "Notepad Document",
    "Microsoft Word": "Microsoft Word Document",
    "Microsoft word": "Microsoft Word Document",
    "microsoft word frm" : "Microsoft Word Document",
    "Microsoft PowerPoint" : "Presentation Document",
    "_Microsoft": "Microsoft Word Document",
     "document": "Microsoft Word Document",
    "scan": "Scanned Document",
    "log": "System Log File",
    "error log": "System Log File",
    "presentation": "Presentation Document",
    "report": "Financial Report",
    "invoice": "Billing Document",
    "billing": "Billing Document",
    "summary": "System-Generated Report"
}

# %%
# Classifying the job

def classify_job(job_name):
    job_name = str(job_name)
    job_name_lower = job_name.lower()

    # check extension
    ext = get_extension(job_name)
    if ext in extension_mapping:
        return extension_mapping[ext]

    # First, check if the job is in our dictionary
    # First: check full job_classification_dict (exact match)
    for key in job_classification_dict:
        if key.lower() == job_name_lower:
            return job_classification_dict[key]

    # Check if any pattern appears in the job name
    # Then: check pattern-based match (substring match)
    for pattern in pattern_classification_dict:
        if pattern.lower() in job_name_lower:
            return pattern_classification_dict[pattern]
    # if not in extension , check for patterns
    #for pattern, category in pattern_classification_dict.items():
       # if pattern in job_name_lower:
         #return category

    # If all else fails, mark as "Other"
    return "Other"

# %%
df_printer1["FileExtension"] = df_printer1["JobName"].apply(get_extension)
df_printer1["JobCategory"] = df_printer1["JobName"].apply(classify_job)
#df_printer1["JobCategory"] = df_printer1["JobCategory"].apply(pattern_classification_dict)

# Display the categorized data
#import ace_tools as tools
#tools.display_dataframe_to_user(name="Classified Print Jobs", dataframe=df_printer.head(50))

# %%
#df_printer1["JobCategory"] = df_printer1["JobName"].apply(normalize_job_name)

# %%
df_printer1.groupby("JobCategory").count()
# Out:
#                                   TrackingId  SafeComName  ComputerName  \
# JobCategory
# Active Server Page Extended file          17           17            17
# Data File                                  7            7             7
# Email Print Job                         8790         8790          8790
# Excel Spreadsheet                        512          512           512
# Financial Report                          55           55            55
# Image File                                 1            1             1
# Microsoft Word Document                 1555         1555          1555
# Notepad Document                          10           10            10
# Other                                   1889         1889          1889
# PDF Document                            2756         2756          2756
# PHP Script                                15           15            15
# Presentation Document                    206          206           206
# Scanned Document                           2            2             2
# Snagit screen capture software            22           22            22
# System Log File                           13           13            13
# System-Generated Report                   14           14            14
# Temporary System File                     10           10            10
# Web Page                                   8            8             8
# document                                 134          134           134
#
#                                   StartDateTime  EndDateTime  ParserPageCount  \
# JobCategory
# Active Server Page Extended file             17           17               17
# Data File                                     7            7                7
# Email Print Job                            8790         8790             8790
# Excel Spreadsheet                           512          512              512
# Financial Report                             55           55               55
# Image File                                    1            1                1
# Microsoft Word Document                    1555         1555             1555
# Notepad Document                             10           10               10
# Other                                      1889         1889             1889
# PDF Document                               2756         2756             2756
# PHP Script                                   15           15               15
# Presentation Document                       206          206              206
# Scanned Document                              2            2                2
# Snagit screen capture software               22           22               22
# System Log File                              13           13               13
# System-Generated Report                      14           14               14
# Temporary System File                        10           10               10
# Web Page                                      8            8                8
# document                                    134          134              134
#
#                                   DriverPageCount  TrackingPageCount  \
# JobCategory
# Active Server Page Extended file               17                 17
# Data File                                       7                  7
# Email Print Job                              8790               8790
# Excel Spreadsheet                             512                512
# Financial Report                               55                 55
# Image File                                      1                  1
# Microsoft Word Document                      1555               1555
# Notepad Document                               10                 10
# Other                                        1889               1889
# PDF Document                                 2756               2756
# PHP Script                                     15                 15
# Presentation Document                         206                206
# Scanned Document                                2                  2
# Snagit screen capture software                 22                 22
# System Log File                                13                 13
# System-Generated Report                        14                 14
# Temporary System File                          10                 10
# Web Page                                        8                  8
# document                                      134                134
#
#                                   PageCountStatus  PageCountSenseCode  ...  \
# JobCategory                                                            ...
# Active Server Page Extended file               17                  17  ...
# Data File                                       7                   7  ...
# Email Print Job                              8790                8790  ...
# Excel Spreadsheet                             512                 512  ...
# Financial Report                               55                  55  ...
# Image File                                      1                   1  ...
# Microsoft Word Document                      1555                1555  ...
# Notepad Document                               10                  10  ...
# Other                                        1889                1889  ...
# PDF Document                                 2756                2756  ...
# PHP Script                                     15                  15  ...
# Presentation Document                         206                 206  ...
# Scanned Document                                2                   2  ...
# Snagit screen capture software                 22                  22  ...
# System Log File                                13                  13  ...
# System-Generated Report                        14                  14  ...
# Temporary System File                          10                  10  ...
# Web Page                                        8                   8  ...
# document                                      134                 134  ...
#
#                                   DeviceIpAddr  JobName  JobDateTime  JobSize  \
# JobCategory
# Active Server Page Extended file            17       17           17       17
# Data File                                    7        7            7        7
# Email Print Job                           8790     8790         8790     8790
# Excel Spreadsheet                          512      512          512      512
# Financial Report                            55       55           55       55
# Image File                                   1        1            1        1
# Microsoft Word Document                   1555     1555         1555     1555
# Notepad Document                            10       10           10       10
# Other                                     1888     1888         1888     1888
# PDF Document                              2756     2756         2756     2756
# PHP Script                                  15       15           15       15
# Presentation Document                      206      206          206      206
# Scanned Document                             2        2            2        2
# Snagit screen capture software              22       22           22       22
# System Log File                             13       13           13       13
# System-Generated Report                     14       14           14       14
# Temporary System File                       10       10           10       10
# Web Page                                     8        8            8        8
# document                                   134      134          134      134
#
#                                   JobDriverName  PMQueueName  PMPortName  \
# JobCategory
# Active Server Page Extended file             17           17          17
# Data File                                     7            7           7
# Email Print Job                             525          525         525
# Excel Spreadsheet                           512          512         512
# Financial Report                             55           55          55
# Image File                                    1            1           1
# Microsoft Word Document                    1555         1555        1555
# Notepad Document                             10           10          10
# Other                                      1214         1214        1214
# PDF Document                               2756         2756        2756
# PHP Script                                   15           15          15
# Presentation Document                       206          206         206
# Scanned Document                              2            2           2
# Snagit screen capture software               22           22          22
# System Log File                              13           13          13
# System-Generated Report                      14           14          14
# Temporary System File                        10           10          10
# Web Page                                      8            8           8
# document                                    129          129         129
#
#                                   PMComputerName  DocComputerName  \
# JobCategory
# Active Server Page Extended file              17               17
# Data File                                      7                7
# Email Print Job                              525              525
# Excel Spreadsheet                            512              512
# Financial Report                              55               55
# Image File                                     1                1
# Microsoft Word Document                     1555             1555
# Notepad Document                              10               10
# Other                                       1296             1296
# PDF Document                                2756             2756
# PHP Script                                    15               15
# Presentation Document                        206              206
# Scanned Document                               2                2
# Snagit screen capture software                22               22
# System Log File                               13               13
# System-Generated Report                       14               14
# Temporary System File                         10               10
# Web Page                                       8                8
# document                                     129              129
#
#                                   FileExtension
# JobCategory
# Active Server Page Extended file             17
# Data File                                     7
# Email Print Job                            8790
# Excel Spreadsheet                           512
# Financial Report                             55
# Image File                                    1
# Microsoft Word Document                    1555
# Notepad Document                             10
# Other                                      1889
# PDF Document                               2756
# PHP Script                                   15
# Presentation Document                       206
# Scanned Document                              2
# Snagit screen capture software               22
# System Log File                              13
# System-Generated Report                      14
# Temporary System File                        10
# Web Page                                      8
# document                                    134
#
# [19 rows x 22 columns]

# %%
df_printer1.to_csv("classified_print_jobs.csv", index=False)
