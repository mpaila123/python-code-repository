# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_h1recon = pd.read_csv('H1reconfile.csv')
df_h1recon.head()
# Out:
#                               Solution       Capabilty  \
# 0   Insights and Commercial Solutions    SFE Products
# 1   Insights and Commercial Solutions    SFE Products
# 2   Insights and Commercial Solutions    SFE Products
# 3   Insights and Commercial Solutions    SFE Products
# 4   Insights and Commercial Solutions    SFE Products
#
#                SOW Item ID             SOW ID Enagagement Name    Region  \
# 0   SOW-2024-019441_33310    SOW-2024-019441     China (CN06)     China
# 1   SOW-2024-019577_33534    SOW-2024-019577            Kenya      APMA
# 2   SOW-2024-019853_34389    SOW-2024-019853        Australia      APMA
# 3   SOW-2024-019481_33363    SOW-2024-019481          Belgium    Europe
# 4   SOW-2024-019481_33364    SOW-2024-019481          Belgium    Europe
#
#                   Project Description / Invoice Text  \
# 0   Incentive calculations for China - 2024 and r...
# 1   Incentive calculation for FWA, EWA and EEA fo...
# ...

# %%
df_h1recon.columns
# Out:
# Index(['Solution', 'Capabilty', 'SOW Item ID', 'SOW ID', 'Enagagement Name',
#        'Region', 'Project Description / Invoice Text',
#        'FY SOW approved amount (=A)', 'FY SOW new estimate'],
#       dtype='object')

# %%
df_h1recon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2347 entries, 0 to 2346
# Data columns (total 9 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Solution                            2347 non-null   object
#  1   Capabilty                           2347 non-null   object
#  2   SOW Item ID                         2347 non-null   object
#  3   SOW ID                              2347 non-null   object
#  4   Enagagement Name                    2347 non-null   object
#  5   Region                              2347 non-null   object
#  6   Project Description / Invoice Text  2347 non-null   object
#  7   FY SOW approved amount (=A)         2347 non-null   object
#  8   FY SOW new estimate                 2347 non-null   object
# dtypes: object(9)
# memory usage: 165.1+ KB

# %%
df_h1recon = df_h1recon.rename(columns={'SOW Item ID': 'SOW line item ID'})

# %%
df_h1recon.columns
# Out:
# Index(['Solution', 'Capabilty', 'SOW line item ID', 'SOW ID',
#        'Enagagement Name', 'Region', 'Project Description / Invoice Text',
#        'FY SOW approved amount (=A)', 'FY SOW new estimate'],
#       dtype='object')

# %%
df_gbs = pd.read_csv('GBSprojects2024.csv')
df_gbs.head()
# Out:
#        Number      Parent                                       Project Name  \
# 0  PRJ1123659  PRJ1123649  Pluvicto Q1 2024 Forecast support - Inline and...
# 1  PRJ1123869  PRJ1123859  Oncology Ribociclib Joint Breast Cancer Regist...
# 2  PRJ1123945  PRJ1123934   Q1 Integrated Insights Support for Cosentyx LCM
# 3  PRJ1124085  PRJ0663267                                    US JAMS Q1 2024
# 4  PRJ1124244  PRJ1124238                   Q1: Website Analytics Consulting
#
#                                          Description             State  \
# 0  Pluvicto Q1 2024 Forecast support - Inline and...   Closed Complete
# 1  Novartis Singapore has requested the support o...  Work in Progress
# 2   Q1 Integrated Insights Support for Cosentyx LCM    Closed Complete
# 3                                            US JAMS  Work in Progress
# 4  Providing Analytics & Insights across brands f...   Closed Complete
#
#                                    Solution              Capability  \
# ...
